# %% [markdown]
# Crowd count detection

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="VV910f4HJtmObQJ0PiiB")
project = rf.workspace("nourhan-mostafa-jaw2n").project("crowded-object-detection")
version = project.version(2)
dataset = version.download("yolov9")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 768.2 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 2.7 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# jupyterlab 4.2.3 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.4.1 which is incompatible.
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 751.8 kB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.5/865.5 kB 6.7 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# %load /kaggle/working/Crowded-Object-Detection-2/data.yaml
names:
- people_counterv0 - v1 2023-05-18 6-22pm
nc: 1
roboflow:
  license: CC BY 4.0
  project: crowded-object-detection
  url: https://universe.roboflow.com/nourhan-mostafa-jaw2n/crowded-object-detection/dataset/2
  version: 2
  workspace: nourhan-mostafa-jaw2n
test: ../test/images
train: Crowded-Object-Detection-2/train/images
val: Crowded-Object-Detection-2/valid/images

# %%
# %%writefile /kaggle/working/Crowded-Object-Detection-2/data.yaml
# # %load /kaggle/working/Crowded-Object-Detection-2/data.yaml
#
# names:
# - Human
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: crowded-object-detection
#   url: https://universe.roboflow.com/nourhan-mostafa-jaw2n/crowded-object-detection/dataset/2
#   version: 2
#   workspace: nourhan-mostafa-jaw2n
# test: /kaggle/working/Crowded-Object-Detection-2/test/images
# train: /kaggle/working/Crowded-Object-Detection-2/train/images
# val: /kaggle/working/Crowded-Object-Detection-2/valid/images
# Out:
# Overwriting /kaggle/working/Crowded-Object-Detection-2/data.yaml

# %%
# %load /kaggle/working/Crowded-Object-Detection-2/data.yaml
# %load /kaggle/working/Crowded-Object-Detection-2/data.yaml

names:
- Human
nc: 1
roboflow:
  license: CC BY 4.0
  project: crowded-object-detection
  url: https://universe.roboflow.com/nourhan-mostafa-jaw2n/crowded-object-detection/dataset/2
  version: 2
  workspace: nourhan-mostafa-jaw2n
test: /kaggle/working/Crowded-Object-Detection-2/test/images
train: /kaggle/working/Crowded-Object-Detection-2/train/images
val: /kaggle/working/Crowded-Object-Detection-2/valid/images

# %%
import torch
torch.cuda.empty_cache()

# %%
import os
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'max_split_size_mb:512'

# %%
from ultralytics import YOLO


# Load a model
#model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8l.pt")  # load a pretrained model (recommended for training)

# Use the model
model.train(data="/kaggle/working/Crowded-Object-Detection-2/data.yaml", epochs=30,batch=2)  # train the model
# Out:
# Ultralytics YOLOv8.2.74 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
torch.cuda.memory_summary(device=None, abbreviated=False)
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 85           |        cudaMalloc retries: 87        |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |   4431 MiB |  14798 MiB | 187743 MiB | 183312 MiB |\n|       from large pool |   4319 MiB |  14558 MiB | 184005 MiB | 179686 MiB |\n|       from small pool |    112 MiB |    266 MiB |   3738 MiB |   3626 MiB |\n|---------------------------------------------------------------------------|\n| Active memory         |   4431 MiB |  14798 MiB | 187743 MiB | 183312 MiB |\n|       from large pool |   4319 MiB |  14558 MiB
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.2.74 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 268 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /kaggle/working/Crowded-Object-Detection-2/valid/labels.cache... 450 images, 0 backgrounds, 0 corrupt: 100%|██████████| 450/450 [00:00<?, ?it/s]
# val: WARNING ⚠️ /kaggle/working/Crowded-Object-Detection-2/valid/images/img_407_jpg.rf.ede8f444f984720c5e9245970c70831e.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/Crowded-Object-Detection-2/valid/images/img_476_jpg.rf.c4519187034a6b23c9bcc696088a4268.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /kaggle/working/Crowded-Object-Detection-2/valid/images/img_529_jpg.rf.887d4f86dbbf8d4d3feb67588acec2b9.jpg: 1 duplicate labels removed
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# ...
